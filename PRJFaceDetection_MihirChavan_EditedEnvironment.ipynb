# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people1.jpg')
display (image.shape)
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[ 91 103 107]
#   [102 114 118]
#   [ 92 107 110]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 93 105 109]
#   [ 97 109 113]
#   [ 95 110 113]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 96 111 114]
#   [ 96 111 114]
#   [102 117 120]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]
#
#  ...
#
#  [[ 48  43  40]
#   [ 46  41  38]
#   [ 44  39  36]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [251 246 243]]
#
#  [[ 55  49  44]
#   [ 53  47  42]
#   [ 49  43  38]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [252 247 244]]
#
#  [[ 56  50  45]
#   [ 54  48  43]
#   [ 50  44  39]
#   ...
#   [252 249 245]
#   [253 248 245]
#   [253 248 245]]]

# %%
cv2.imshow('', image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.resize(image, (800, 600))

image.shape
# Out:
# (600, 800, 3)

# %%
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
display (image_gray.shape)
# Out:
# (600, 800)

# %%
plt.imshow(image_gray)
plt.show()

# %%
face_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\haarcascade_frontalface_default.xml')
face_detector
# Out:
# < cv2.CascadeClassifier 0000022820071CD0>

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
# Out:
# array([[115, 124,  53,  53],
#        [677,  72,  68,  68],
#        [475, 123,  59,  59],
#        [390, 323,  56,  56],
#        [387, 233,  73,  73],
#        [ 92, 239,  66,  66]])

# %%
display (len(detections))
# Out:
# 6

# %%
x=390  # X - Co ordinates 
y=323  # Y- Co ordinates 
w=56  # Face Width
h=56  # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 1)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
x=115  # X - Co ordinates 
y=124  # Y- Co ordinates 
w=52   # Face Width
h=52   # Face Height 
# Thickness is 5 , more thicker rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
x=475  # X - Co ordinates 
y=123  # Y- Co ordinates 
w=59   # Face Width
h=59  # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
plt.show()

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people1.jpg')
display (image.shape)
image = cv2.resize(image, (800, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (1280, 1920, 3)
# (600, 800, 3)
# array([[115, 124,  53,  53],
#        [677,  72,  68,  68],
#        [475, 123,  59,  59],
#        [390, 323,  56,  56],
#        [387, 233,  73,  73],
#        [ 92, 239,  66,  66]])

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[113, 122,  56,  56],
#        [475, 122,  60,  60],
#        [678,  74,  65,  65],
#        [386, 232,  74,  74],
#        [ 90, 238,  69,  69]])

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[462, 378,  27,  27],
#        [718, 101,  44,  44],
#        [692, 153,  44,  44],
#        [324,  49,  45,  45],
#        [424,  32,  46,  46],
#        [461, 367,  33,  33],
#        [600,  61,  49,  49],
#        [907,  63,  50,  50],
#        [235,  45,  51,  51],
#        [380,  53,  54,  54],
#        [168,  35,  50,  50],
#        [825,  90,  51,  51],
#        [479,  69,  47,  47],
#        [663,  83,  43,  43],
#        [ 91,  81,  50,  50]])
# 27 27
# 44 44
# 44 44
# 45 45
# 46 46
# 33 33
# 49 49
# 50 50
# 51 51
# 54 54
# 50 50
# 51 51
# 47 47
# 43 43
# 50 50

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people2.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,minNeighbors=7)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[717, 100,  46,  46],
#        [321,  48,  47,  47],
#        [424,  31,  47,  47],
#        [600,  60,  49,  49],
#        [168,  35,  49,  49],
#        [380,  54,  52,  52],
#        [906,  63,  51,  51],
#        [234,  46,  50,  50],
#        [662,  83,  44,  44],
#        [ 91,  81,  51,  51],
#        [480,  70,  47,  47],
#        [825,  91,  51,  51]])
# 46 46
# 47 47
# 47 47
# 49 49
# 49 49
# 52 52
# 51 51
# 50 50
# 44 44
# 51 51
# 47 47
# 51 51

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,
                                            minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[424,  31,  47,  47],
#        [168,  35,  49,  49],
#        [717, 100,  46,  46],
#        [321,  48,  47,  47],
#        [600,  60,  49,  49],
#        [380,  54,  52,  52],
#        [906,  63,  51,  51],
#        [234,  46,  50,  50],
#        [ 91,  81,  51,  51],
#        [662,  83,  44,  44],
#        [825,  91,  51,  51],
#        [480,  70,  47,  47]])
# 47 47
# 49 49
# 46 46
# 47 47
# 49 49
# 52 52
# 51 51
# 50 50
# 51 51
# 44 44
# 51 51
# 47 47

# %%
eye_detector= cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\haarcascade_eye.xml')

display (eye_detector)
# Out:
# < cv2.CascadeClassifier 0000022820489250>

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (1280, 1920, 3)
# (1000, 1600, 3)
# 22 22
# 30 30
# 23 23
# 22 22
# 29 29
# 33 33
# 31 31
# 25 25
# 33 33

# %%
car_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\cars.xml')

display (car_detector)
# Out:
# < cv2.CascadeClassifier 0000022820489170>

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\car.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (286, 468, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
clock_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\clocks.xml')
display (clock_detector)
# Out:
# < cv2.CascadeClassifier 00000228204893B0>

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\clock.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (438, 450, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = clock_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
full_detector  = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\fullbody.xml')
display (full_detector)
# Out:
# < cv2.CascadeClassifier 00000228204895B0>

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people3.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (294, 626, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray, scaleFactor = 1.05, minNeighbors=5,
                                              minSize = (50,50)) 
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
import dlib

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1) # 1 – is the scale factor

# %%
display (len(detections))
display (detections)
# Out:
# 14
# rectangles[[(429, 38) (465, 74)], [(665, 90) (701, 126)], [(717, 103) (760, 146)], [(909, 70) (952, 113)], [(828, 98) (871, 142)], [(605, 70) (641, 106)], [(777, 62) (813, 98)], [(485, 78) (521, 114)], [(386, 60) (429, 103)], [(170, 41) (213, 84)], [(93, 89) (136, 132)], [(237, 50) (280, 94)], [(323, 50) (367, 94)], [(544, 65) (588, 108)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# [(429, 38) (465, 74)]
# 429
# 38
# 465
# 74
# -1

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Weights\\mmod_human_face_detector.dat')
cnn_detector

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# 1.1440682411193848
# 1.137049913406372
# 1.1278996467590332
# 1.1200228929519653
# 1.1149370670318604
# 1.1131553649902344
# 1.097571611404419
# 1.0942120552062988
# 1.085314154624939
# 1.0801892280578613
# 1.0800764560699463
# 1.0784764289855957
# 1.0664036273956299
# 1.0641793012619019
# -1

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
haarcascade_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\haarcascade_frontalface_default.xml')
detections = haarcascade_detector.detectMultiScale(image_gray, scaleFactor = 1.001, minNeighbors=5, minSize = (5,5))
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\people3.jpg')
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 4)
for face in detections:
    l, t, r, b = (face.left(), face.top(), face.right(), face.bottom())
    cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
##############################################

# %%
###########################

# %%
############

# %%
#Modifications to project and new picture used

# %%
#############

# %%
##############################

# %%
#############################################

# %%
#method 1    {Cascade Classifier and open CV}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
display (image.shape)
image = cv2.resize(image, (800, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (575, 1024, 3)
# (600, 800, 3)
# array([[139, 301, 105, 105],
#        [239, 248,  83,  83],
#        [333, 208, 107, 107]])

# %%
# 3 faces detected   {for loop}

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
#method 2- 4 faces detected                {scaleFactor,for loop}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[333, 207, 106, 106],
#        [139, 299, 106, 106],
#        [239, 247,  83,  83],
#        [410, 258, 109, 109]])

# %%
#method 3

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
# 5 faces detected but not accurate           {scaleFactor,minNeighbours}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.1,minNeighbors=4)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[627, 158,  69,  69],
#        [437, 196, 111, 111],
#        [314, 229,  93,  93],
#        [187, 281, 117, 117],
#        [547, 246, 106, 106]])
# 69 69
# 111 111
# 93 93
# 117 117
# 106 106

# %%
# method 4-5 faces detected but not accurate           {scaleFactor,minNeighbours,minSize,maxSize}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.1,
                                            minNeighbors=4,minSize=(50,50), maxSize=(700,700))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 4)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[627, 158,  69,  69],
#        [314, 229,  93,  93],
#        [437, 196, 111, 111],
#        [547, 246, 106, 106],
#        [187, 281, 117, 117]])
# 69 69
# 93 93
# 111 111
# 106 106
# 117 117

# %%
# method 5- 6 accurate detections out 0f 7 faces          {dlib library}

# %%
import dlib

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1) # 1 – is the scale factor

# %%
display (len(detections))
display (detections)
# Out:
# 6
# rectangles[[(187, 295) (294, 402)], [(444, 216) (534, 305)], [(320, 246) (395, 320)], [(641, 199) (748, 307)], [(563, 265) (653, 355)], [(666, 81) (820, 236)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# [(187, 295) (294, 402)]
# 187
# 295
# 294
# 402
# -1

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
# method 6- all 7 face detected, some faces are double boxed               {CNN library}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Weights\\mmod_human_face_detector.dat')
cnn_detector

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 6)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# 1.1226933002471924
# 1.1169848442077637
# 1.1133716106414795
# 1.1114284992218018
# 1.091457724571228
# 1.0544626712799072
# 0.970070481300354
# 0.06736510992050171
# -1

# %%
# method 7- 5 faces detected but not accurate           { Haarcascade}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
haarcascade_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\haarcascade_frontalface_default.xml')
detections = haarcascade_detector.detectMultiScale(image_gray, scaleFactor = 1.04, minNeighbors=4, minSize = (5,5))
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
# method 8- 6 faces detected     { HOG ie Histogram of Oriented Gradients }

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 4)
for face in detections:
    l, t, r, b = (face.left(), face.top(), face.right(), face.bottom())
    cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 5)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
# method 9- 5 detections but not accurate {CascadeClassifier,for loop,resize}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
display (image.shape)
# Out:
# (575, 1024, 3)

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[ 33 130 104]
#   [ 90 144 127]
#   [172 175 166]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [255 255 255]]
#
#  [[106 135 120]
#   [135 159 147]
#   [182 197 189]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [255 255 255]]
#
#  [[195 176 171]
#   [196 197 188]
#   [210 225 217]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[192 100  57]
#   [163  80  28]
#   [178 111  42]
#   ...
#   [ 29  27  27]
#   [ 32  30  30]
#   [ 46  44  44]]
#
#  [[195 128  71]
#   [205 156  82]
#   [223 195 100]
#   ...
#   [ 30  28  28]
#   [ 33  31  31]
#   [ 47  45  45]]
#
#  [[237 218 127]
#   [215 199 103]
#   [213 201  99]
#   ...
#   [ 46  44  44]
#   [ 49  47  47]
#   [ 63  61  61]]]

# %%
cv2.imshow('', image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.resize(image, (700, 600))

image.shape
# Out:
# (600, 700, 3)

# %%
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
display (image_gray.shape)
# Out:
# (600, 700)

# %%
plt.imshow(image_gray)
plt.show()

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
# Out:
# array([[287, 215,  97,  97],
#        [206, 250,  77,  77]])

# %%
face_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\haarcascade_frontalface_default.xml')
face_detector
# Out:
# < cv2.CascadeClassifier 000002281FFE2ED0>

# %%
display (len(detections))
# Out:
# 2

# %%
x=390  # X - Co ordinates 
y=323  # Y- Co ordinates 
w=56  # Face Width
h=56  # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 1)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
x=115  # X - Co ordinates 
y=124  # Y- Co ordinates 
w=52   # Face Width
h=52   # Face Height 
# Thickness is 5 , more thicker rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
x=475  # X - Co ordinates 
y=123  # Y- Co ordinates 
w=59   # Face Width
h=59  # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
plt.show()

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\ppl1.jpg')
display (image.shape)
image = cv2.resize(image, (1000, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (575, 1024, 3)
# (600, 1000, 3)
# array([[612, 166,  68,  68],
#        [423, 206, 113, 113],
#        [536, 259, 106, 106],
#        [304, 242,  93,  93],
#        [181, 296, 119, 119]])

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
#New picture m1---- { cnn detector on family photo------all 6 faces detected with 100% accuracy----takes a bit time to load}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\family.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Weights\\mmod_human_face_detector.dat')
cnn_detector

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 6)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# 1.0863302946090698
# 1.084884524345398
# 1.0807057619094849
# 1.0665452480316162
# 1.061548113822937
# 1.054997205734253
# -1

# %%
#New picture m2---- { dlib  on family photo------all 6 faces detected with 100% accuracy----fast loading}

# %%
import dlib

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\family.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1) # 1 – is the scale factor

# %%
display (len(detections))
display (detections)
# Out:
# 6
# rectangles[[(122, 166) (165, 209)], [(493, 174) (529, 210)], [(218, 170) (261, 214)], [(321, 166) (357, 202)], [(405, 206) (441, 242)], [(577, 149) (640, 211)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# [(122, 166) (165, 209)]
# 122
# 166
# 165
# 209
# -1

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
#New picture m3---- { hog  on family photo------all 6 faces detected with 100% accuracy----fast loading}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\family.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 4)
for face in detections:
    l, t, r, b = (face.left(), face.top(), face.right(), face.bottom())
    cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 5)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
#New picture m4---- { cascade[face_detector.detectMultiScale] & for loop  on family photo------all 
#6 faces detected with 100% accuracy----fast loading, but scale factor has to be adjusted by trial and error}

# %%
image = cv2.imread('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\family.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.08,
                                            minNeighbors=7,minSize=(50,50), maxSize=(600,600))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 4)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[312, 152,  57,  57],
#        [483, 160,  56,  56],
#        [114, 160,  57,  57],
#        [212, 161,  58,  58],
#        [581, 145,  63,  63],
#        [397, 192,  55,  55]])
# 57 57
# 56 56
# 57 57
# 58 58
# 63 63
# 55 55

# %%
############################
#Thus,best & easy to use libraries so far for face detection are 
# cnn- 100 percent accurate but slow 
# dlib- almost 100% accurate and fast
#############################

# %%
################################### Live web-cam video face detection using openCV and while loop   ####################

# %%
import cv2
face_detector = cv2.CascadeClassifier('C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Cascades\\haarcascade_frontalface_default.xml')

cap=cv2.VideoCapture(0)
while True:
    _,img=cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(gray, scaleFactor = 1.125, minNeighbors=2)
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0,255,0), 4)
    cv2.imshow('web cam',img)
    
    k=cv2.waitKey(30) & 0xff
    if k==27:
        break            # breaks the loop if escape key is pressed
        
cap.release()
cv2.destroyAllWindows()

# %%
################## Webcam Face Recognition Attendance system    ################

# %%
#Here, the webcam will capture pics of students and update their attendance with name and time in csv file.
#OpenCV,face_recognition are main libraries used
#Mihir Chavan
import face_recognition
import cv2
import numpy as np
import csv
import os
from datetime import datetime 

video_capture=cv2.VideoCapture(0)

jobs_image=face_recognition.load_image_file("C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\Steve_Jobs_image.jpg")
jobs_encoding=face_recognition.face_encodings(jobs_image)[0]

ratan_tata_image=face_recognition.load_image_file("C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\Ratan_Tata_image.jpg")
ratan_tata_encoding=face_recognition.face_encodings(ratan_tata_image)[0]

mukesh_ambani_image=face_recognition.load_image_file("C:\\Users\\HP\\ML acme practice\\Face detection project_python_ml\\Data Set\\Mukesh_Ambani_image.jpg")
mukesh_ambani_encoding=face_recognition.face_encodings(mukesh_ambani_image)[0]

known_face_encoding=[
    jobs_encoding,
    ratan_tata_encoding,
    mukesh_ambani_encoding
]

known_faces_names=[
    "Steve Jobs",
    "Ratan Tata",
    "Mukesh Ambani"
]

students=known_faces_names.copy()

face_locations=[]
face_encodings=[]
face_names=[]
s=True

now=datetime.now()
current_date=now.strftime("%Y-%m-%d")
f=open(current_date+'.csv','w+',newline='')
lnwriter=csv.writer(f)

while True:
    _,frame=video_capture.read()
    small_frame=cv2.resize(frame,(0,0),fx=0.25,fy=0.25)
    rgb_small_frame=small_frame[:,:,::-1]
    if s:
        face_locations=face_recognition. face_locations (rgb_small_frame)
        face_encodings=face_recognition. face_encodings (rgb_small_frame, face_locations)
        face_names =[]
        for face_encoding in face_encodings:
            matches=face_recognition.compare_faces (known_face_encoding, face_encoding) 
            name=""
            face_distance =face_recognition. face_distance (known_face_encoding, face_encoding) 
            best_match_index= np.argmin (face_distance)
            if matches[best_match_index]:
                name=known_faces_names[best_match_index]
                
            face_names.append(name)
            if name in known_faces_names:
                if name in students:
                    students.remove(name) 
                    print(students)
                    current_time = now.strftime("%H-%M-%S") 
                    lnwriter.writerow([name, current_time])
                    
    cv2.imshow("Attendance System",frame)
    if cv2.waitKey(1) & 0xff==ord('q'):
        break
                    
video_capture.release()
cv2.destroyAllWindows()
f.close()
# Out:
# ['Steve Jobs', 'Ratan Tata']

# %%
#End of project
